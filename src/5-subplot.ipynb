# %% [markdown]
# ### Exercise 5: Subplot Layout

# %%
# TASK: Create a 2x2 subplot layout.
# Plot a line chart in the first subplot, a bar chart in the second, a scatter plot in the third, and a pie chart in the fourth.
import matplotlib.pyplot as plt

# Sample Data
x = [1, 2, 3, 4, 5]
y1 = [2, 4, 1, 5, 2]
categories = ['A', 'B', 'C', 'D']
values = [25, 15, 30, 20]
x2 = [1, 2, 3, 4]
y2 = [3, 1, 4, 2]
labels = ['Apples', 'Bananas', 'Oranges', 'Grapes']
sizes = [30, 25, 15, 30]


# Create a 2x2 subplot grid
fig, axes = plt.subplots(2, 2)

# Plot a line chart in the first subplot (top-left)
axes[0, 0].plot(x, y1)
axes[0, 0].set_title('Line Chart')

# Plot a bar chart in the second subplot (top-right)
axes[0, 1].bar(categories, values)
axes[0, 1].set_title('Bar Chart')

# Plot a scatter plot in the third subplot (bottom-left)
axes[1, 0].scatter(x2, y2)
axes[1, 0].set_title('Scatter Plot')

# Plot a pie chart in the fourth subplot (bottom-right)
axes[1, 1].pie(sizes, labels=labels, autopct='%1.1f%%')
axes[1, 1].set_title('Pie Chart')
axes[1, 1].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.


# Adjust layout to prevent overlapping titles/labels
plt.tight_layout()

# Show the plot
plt.show()
